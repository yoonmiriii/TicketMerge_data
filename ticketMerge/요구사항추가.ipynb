# %% [markdown]
# #### 임의로 공연장르와 공연장 위치 넣어주기

# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('../ticketMerge/df_total.csv')

# %%
df
# Out:
#      Unnamed: 0                                              title  \
# 0             0   2024 TREASURE RELAY TOUR ［REBOOT］ FINAL IN SEOUL
# 1             1                                         두아 리파 내한공연
# 2             2                          싸이흠뻑쇼 SUMMERSWAG2024 - 인천
# 3             3                          송소희, 두번째달, 김준수의 모던민요 - 여주
# 4             4                          싸이흠뻑쇼 SUMMERSWAG2024 - 대구
# ..          ...                                                ...
# 506         506         프레드 허쉬 Solo Piano 2024 - Silent, Listening
# 507         507  CHO TOKIMEKI SENDENBU KIMINO HEART NI ROCK ON ...
# 508         508  eaJ Live in Seoul ＂when the rain stopped follo...
# 509         509    EMOTIONAL ORANGES LIVE IN SEOUL 이모셔널 오렌지스 내한 공연
# 510         510                      NEKIRU 5th ONEMAN LIVE 「낭만주의」
#
#                                           thumbnailUrl  \
# 0    http://ticketimage.interpark.com/Play/image/la...
# ...

# %%
# 랜덤숫자 생성해서 장르와 지역 컬럼 만들어 넣어주고, 숫자를 장르와 지역으로 변경해 주기

# %%
# 발라드, 댄스, 힙합, 락, 트로트, 내한, 그 외
# 7종류 넣어주기

# %%
genre = pd.DataFrame(np.random.randint(0, 6+1,size=(510+1, 1)))

# %%
genre
# Out:
#      0
# 0    1
# 1    6
# 2    3
# 3    0
# 4    0
# ..  ..
# 506  6
# 507  2
# 508  3
# 509  3
# 510  1
#
# [511 rows x 1 columns]

# %%
df['genre'] = genre

# %%
df
# Out:
#      Unnamed: 0                                              title  \
# 0             0   2024 TREASURE RELAY TOUR ［REBOOT］ FINAL IN SEOUL
# 1             1                                         두아 리파 내한공연
# 2             2                          싸이흠뻑쇼 SUMMERSWAG2024 - 인천
# 3             3                          송소희, 두번째달, 김준수의 모던민요 - 여주
# 4             4                          싸이흠뻑쇼 SUMMERSWAG2024 - 대구
# ..          ...                                                ...
# 506         506         프레드 허쉬 Solo Piano 2024 - Silent, Listening
# 507         507  CHO TOKIMEKI SENDENBU KIMINO HEART NI ROCK ON ...
# 508         508  eaJ Live in Seoul ＂when the rain stopped follo...
# 509         509    EMOTIONAL ORANGES LIVE IN SEOUL 이모셔널 오렌지스 내한 공연
# 510         510                      NEKIRU 5th ONEMAN LIVE 「낭만주의」
#
#                                           thumbnailUrl  \
# 0    http://ticketimage.interpark.com/Play/image/la...
# ...

# %%
# 서울, 경기, 인천, 강원, 춘천, 속초, 충청, 세종, 대전, 전라, 광주, 경북, 대구, 경남, 부산, 제주
# 16개 지역으로 나누기

# %%
loc = pd.DataFrame(np.random.randint(0, 15+1,size=(510+1, 1)))

# %%
df['location'] = loc

# %%
df
# Out:
#      Unnamed: 0                                              title  \
# 0             0   2024 TREASURE RELAY TOUR ［REBOOT］ FINAL IN SEOUL
# 1             1                                         두아 리파 내한공연
# 2             2                          싸이흠뻑쇼 SUMMERSWAG2024 - 인천
# 3             3                          송소희, 두번째달, 김준수의 모던민요 - 여주
# 4             4                          싸이흠뻑쇼 SUMMERSWAG2024 - 대구
# ..          ...                                                ...
# 506         506         프레드 허쉬 Solo Piano 2024 - Silent, Listening
# 507         507  CHO TOKIMEKI SENDENBU KIMINO HEART NI ROCK ON ...
# 508         508  eaJ Live in Seoul ＂when the rain stopped follo...
# 509         509    EMOTIONAL ORANGES LIVE IN SEOUL 이모셔널 오렌지스 내한 공연
# 510         510                      NEKIRU 5th ONEMAN LIVE 「낭만주의」
#
#                                           thumbnailUrl  \
# 0    http://ticketimage.interpark.com/Play/image/la...
# ...

# %%
# 'Unnamed: 0' 컬럼 삭제하기

# %%
df = df.drop(['Unnamed: 0'], axis=1)

# %%
df
# Out:
#                                                  title  \
# 0     2024 TREASURE RELAY TOUR ［REBOOT］ FINAL IN SEOUL
# 1                                           두아 리파 내한공연
# 2                            싸이흠뻑쇼 SUMMERSWAG2024 - 인천
# 3                            송소희, 두번째달, 김준수의 모던민요 - 여주
# 4                            싸이흠뻑쇼 SUMMERSWAG2024 - 대구
# ..                                                 ...
# 506         프레드 허쉬 Solo Piano 2024 - Silent, Listening
# 507  CHO TOKIMEKI SENDENBU KIMINO HEART NI ROCK ON ...
# 508  eaJ Live in Seoul ＂when the rain stopped follo...
# 509    EMOTIONAL ORANGES LIVE IN SEOUL 이모셔널 오렌지스 내한 공연
# 510                      NEKIRU 5th ONEMAN LIVE 「낭만주의」
#
#                                           thumbnailUrl  \
# 0    http://ticketimage.interpark.com/Play/image/la...
# 1    http://ticketimage.interpark.com/Play/image/la...
# 2    http://ticketimage.interpark.com/Play/image/la...
# 3    http://ticketimage.interpark.com/Play/image/la...
# ...

# %%
# 0=발라드, 1=댄스, 2=힙합, 3=락, 4=트로트, 5=내한, 6=그 외

# %%
df = df.replace({'genre': 0}, '발라드')
df = df.replace({'genre': 1}, '댄스')
df = df.replace({'genre': 2}, '힙합')
df = df.replace({'genre': 3}, '락')
df = df.replace({'genre': 4}, '트로트')
df = df.replace({'genre': 5}, '내한')
df = df.replace({'genre': 6}, '그 외')

# %%
# 0=서울, 1=경기, 2=인천, 3=강원, 4=춘천, 5=속초, 6=충청, 7=세종, 8=대전, 9=전라, 10=광주, 11=경북, 12=대구, 13=경남, 14=부산, 15=제주

# %%
df = df.replace({'location': 0}, '서울')
df = df.replace({'location': 1}, '경기')
df = df.replace({'location': 2}, '인천')
df = df.replace({'location': 3}, '강원')
df = df.replace({'location': 4}, '춘천')
df = df.replace({'location': 5}, '속초')
df = df.replace({'location': 6}, '충청')
df = df.replace({'location': 7}, '세종')
df = df.replace({'location': 8}, '대전')
df = df.replace({'location': 9}, '전라')
df = df.replace({'location': 10}, '광주')
df = df.replace({'location': 11}, '경북')
df = df.replace({'location': 12}, '대구')
df = df.replace({'location': 13}, '경남')
df = df.replace({'location': 14}, '부산')
df = df.replace({'location': 15}, '제주')

# %%
df
# Out:
#                                                  title  \
# 0     2024 TREASURE RELAY TOUR ［REBOOT］ FINAL IN SEOUL
# 1                                           두아 리파 내한공연
# 2                            싸이흠뻑쇼 SUMMERSWAG2024 - 인천
# 3                            송소희, 두번째달, 김준수의 모던민요 - 여주
# 4                            싸이흠뻑쇼 SUMMERSWAG2024 - 대구
# ..                                                 ...
# 506         프레드 허쉬 Solo Piano 2024 - Silent, Listening
# 507  CHO TOKIMEKI SENDENBU KIMINO HEART NI ROCK ON ...
# 508  eaJ Live in Seoul ＂when the rain stopped follo...
# 509    EMOTIONAL ORANGES LIVE IN SEOUL 이모셔널 오렌지스 내한 공연
# 510                      NEKIRU 5th ONEMAN LIVE 「낭만주의」
#
#                                           thumbnailUrl  \
# 0    http://ticketimage.interpark.com/Play/image/la...
# 1    http://ticketimage.interpark.com/Play/image/la...
# 2    http://ticketimage.interpark.com/Play/image/la...
# 3    http://ticketimage.interpark.com/Play/image/la...
# ...

# %%
# 'Unnamed: 0' 컬럼 생기지 않도록 저장하기

# %%
df.to_csv('../ticketMerge/df_total(추가).csv', index=False)

# %% [markdown]
# ##### 요구사항
# * https:https://... 수정하기
# * 장르와 지역 컬럼을 endDate 컬럼 뒤로 변경하기

# %%
# 불러오기

# %%
df = pd.read_csv('../ticketMerge/df_total(추가).csv')

# %%
df
# Out:
#                                                  title  \
# 0     2024 TREASURE RELAY TOUR ［REBOOT］ FINAL IN SEOUL
# 1                                           두아 리파 내한공연
# 2                            싸이흠뻑쇼 SUMMERSWAG2024 - 인천
# 3                            송소희, 두번째달, 김준수의 모던민요 - 여주
# 4                            싸이흠뻑쇼 SUMMERSWAG2024 - 대구
# ..                                                 ...
# 506         프레드 허쉬 Solo Piano 2024 - Silent, Listening
# 507  CHO TOKIMEKI SENDENBU KIMINO HEART NI ROCK ON ...
# 508  eaJ Live in Seoul ＂when the rain stopped follo...
# 509    EMOTIONAL ORANGES LIVE IN SEOUL 이모셔널 오렌지스 내한 공연
# 510                      NEKIRU 5th ONEMAN LIVE 「낭만주의」
#
#                                           thumbnailUrl  \
# 0    http://ticketimage.interpark.com/Play/image/la...
# 1    http://ticketimage.interpark.com/Play/image/la...
# 2    http://ticketimage.interpark.com/Play/image/la...
# 3    http://ticketimage.interpark.com/Play/image/la...
# ...

# %%
# https:https://... 수정하기

# %%
# 해당값이 있는 contentUrl 컬럼을 시리즈로 변경 후 replace 이용하기

# %%
s = df['contentUrl']

# %%
s
# Out:
# 0      https://ticketimage.interpark.com/Play/image/e...
# 1      https://ticketimage.interpark.com/Play/image/e...
# 2      https://ticketimage.interpark.com/Play/image/e...
# 3      https://ticketimage.interpark.com/Play/image/e...
# 4      https://ticketimage.interpark.com/Play/image/e...
#                              ...
# 506    http://tkfile.yes24.com/Upload2/Board/202406/2...
# 507    http://tkfile.yes24.com/Upload2/Board/202406/2...
# 508    http://tkfile.yes24.com/Upload2/Board/202405/2...
# 509    http://tkfile.yes24.com/Upload2/Board/202406/2...
# 510    http://tkfile.yes24.com/Upload2/Board/202406/2...
# Name: contentUrl, Length: 511, dtype: object

# %%
s = s.str.replace('https:https://', 'https://')

# %%
df['contentUrl'] = s

# %%
df
# Out:
#                                                  title  \
# 0     2024 TREASURE RELAY TOUR ［REBOOT］ FINAL IN SEOUL
# 1                                           두아 리파 내한공연
# 2                            싸이흠뻑쇼 SUMMERSWAG2024 - 인천
# 3                            송소희, 두번째달, 김준수의 모던민요 - 여주
# 4                            싸이흠뻑쇼 SUMMERSWAG2024 - 대구
# ..                                                 ...
# 506         프레드 허쉬 Solo Piano 2024 - Silent, Listening
# 507  CHO TOKIMEKI SENDENBU KIMINO HEART NI ROCK ON ...
# 508  eaJ Live in Seoul ＂when the rain stopped follo...
# 509    EMOTIONAL ORANGES LIVE IN SEOUL 이모셔널 오렌지스 내한 공연
# 510                      NEKIRU 5th ONEMAN LIVE 「낭만주의」
#
#                                           thumbnailUrl  \
# 0    http://ticketimage.interpark.com/Play/image/la...
# 1    http://ticketimage.interpark.com/Play/image/la...
# 2    http://ticketimage.interpark.com/Play/image/la...
# 3    http://ticketimage.interpark.com/Play/image/la...
# ...

# %%
# 장르와 지역 컬럼을 endDate 컬럼 뒤로 변경하기

# %%
df.columns
# Out:
# Index(['title', 'thumbnailUrl', 'contentUrl', 'place', 'castigList', 'url',
#        'startDate', 'endDate', 'End_date', 'artist1', 'artist2', 'artist3',
#        'artist4', 'artist5', 'artist6', 'artist7', 'artist8', 'artist9',
#        'artist10', 'artist11', 'artist12', 'artist13', 'artist14', 'artist15',
#        'artist16', 'artist17', 'artist18', 'artist19', 'artist20', 'artist21',
#        'artist22', 'artist23', 'artist24', 'artist25', 'artist26', 'genre',
#        'location'],
#       dtype='object')

# %%
# df_col 변수에 저장 후 df에 적용하기

# %%
df_col = df[['title', 'thumbnailUrl', 'contentUrl', 'place', 'castigList', 'url',
       'startDate', 'endDate', 'genre', 'location','End_date', 'artist1', 'artist2', 'artist3',
       'artist4', 'artist5', 'artist6', 'artist7', 'artist8', 'artist9',
       'artist10', 'artist11', 'artist12', 'artist13', 'artist14', 'artist15',
       'artist16', 'artist17', 'artist18', 'artist19', 'artist20', 'artist21',
       'artist22', 'artist23', 'artist24', 'artist25', 'artist26']]

# %%
df = df_col

# %%
df
# Out:
#                                                  title  \
# 0     2024 TREASURE RELAY TOUR ［REBOOT］ FINAL IN SEOUL
# 1                                           두아 리파 내한공연
# 2                            싸이흠뻑쇼 SUMMERSWAG2024 - 인천
# 3                            송소희, 두번째달, 김준수의 모던민요 - 여주
# 4                            싸이흠뻑쇼 SUMMERSWAG2024 - 대구
# ..                                                 ...
# 506         프레드 허쉬 Solo Piano 2024 - Silent, Listening
# 507  CHO TOKIMEKI SENDENBU KIMINO HEART NI ROCK ON ...
# 508  eaJ Live in Seoul ＂when the rain stopped follo...
# 509    EMOTIONAL ORANGES LIVE IN SEOUL 이모셔널 오렌지스 내한 공연
# 510                      NEKIRU 5th ONEMAN LIVE 「낭만주의」
#
#                                           thumbnailUrl  \
# 0    http://ticketimage.interpark.com/Play/image/la...
# 1    http://ticketimage.interpark.com/Play/image/la...
# 2    http://ticketimage.interpark.com/Play/image/la...
# 3    http://ticketimage.interpark.com/Play/image/la...
# ...

# %% [markdown]
# ##### 요구사항
# * 'genre'와 'location'컬럼에 숫자(1부터 시작)로 된 값이 들어있는 파일 요청

# %%
df = df.replace({'genre': '발라드'}, 1)
df = df.replace({'genre': '댄스'}, 2)
df = df.replace({'genre': '힙합'}, 3)
df = df.replace({'genre': '락'}, 4)
df = df.replace({'genre': '트로트'}, 5)
df = df.replace({'genre': '내한'}, 6)
df = df.replace({'genre': '그 외'}, 7)

# %%
df = df.replace({'location': '서울'}, 1)
df = df.replace({'location': '경기'}, 2)
df = df.replace({'location': '인천'}, 3)
df = df.replace({'location': '강원'}, 4)
df = df.replace({'location': '춘천'}, 5)
df = df.replace({'location': '속초'}, 6)
df = df.replace({'location': '충청'}, 7)
df = df.replace({'location': '세종'}, 8)
df = df.replace({'location': '대전'}, 9)
df = df.replace({'location': '전라'}, 10)
df = df.replace({'location': '광주'}, 11)
df = df.replace({'location': '경북'}, 12)
df = df.replace({'location': '대구'}, 13)
df = df.replace({'location': '경남'}, 14)
df = df.replace({'location': '부산'}, 15)
df = df.replace({'location': '제주'}, 16)

# %%
df
# Out:
#                                                  title  \
# 0     2024 TREASURE RELAY TOUR ［REBOOT］ FINAL IN SEOUL
# 1                                           두아 리파 내한공연
# 2                            싸이흠뻑쇼 SUMMERSWAG2024 - 인천
# 3                            송소희, 두번째달, 김준수의 모던민요 - 여주
# 4                            싸이흠뻑쇼 SUMMERSWAG2024 - 대구
# ..                                                 ...
# 506         프레드 허쉬 Solo Piano 2024 - Silent, Listening
# 507  CHO TOKIMEKI SENDENBU KIMINO HEART NI ROCK ON ...
# 508  eaJ Live in Seoul ＂when the rain stopped follo...
# 509    EMOTIONAL ORANGES LIVE IN SEOUL 이모셔널 오렌지스 내한 공연
# 510                      NEKIRU 5th ONEMAN LIVE 「낭만주의」
#
#                                           thumbnailUrl  \
# 0    http://ticketimage.interpark.com/Play/image/la...
# 1    http://ticketimage.interpark.com/Play/image/la...
# 2    http://ticketimage.interpark.com/Play/image/la...
# 3    http://ticketimage.interpark.com/Play/image/la...
# ...

# %%
df.to_csv('../ticketMerge/df_total(숫자).csv', index=False)

# %%
# 아티스트 파일 수정하기

# %% [markdown]
# ##### 아티스트 성별 추가하기

# %%
df = pd.read_csv('../artists.csv')

# %%
df
# Out:
#      Unnamed: 0                   name  \
# 0             0                    트레저
# 1             1                  두아 리파
# 2             2                     싸이
# 3             3                    이문세
# 4             4                  SG워너비
# ..          ...                    ...
# 548         549                 육중완 밴드
# 549         550  CHO TOKIMEKI SENDENBU
# 550         551                    eaJ
# 551         552                 NEKIRU
# 552         553                  NMIXX
#
#                                                    url
# 0    https://ticketimage.interpark.com/PlayDictiona...
# 1    https://ticketimage.interpark.com/PlayDictiona...
# 2    https://ticketimage.interpark.com/PlayDictiona...
# 3    https://ticketimage.interpark.com/PlayDictiona...
# 4    https://ticketimage.interpark.com/PlayDictiona...
# ..                                                 ...
# 548  https://i.namu.wiki/i/Bge3xnYd4kRe_IKbm2uqxlhQ...
# ...

# %%
import numpy as np

# %%
df1 = np.random.randint(0,1+1, size=(552+1, 1))

# %%
df1['gender'] = pd.DataFrame(df1)

# %%
df1.shape
# Out:
# (553, 1)

# %%
df = pd.concat([df, df1], axis=1)

# %%
df
# Out:
#      Unnamed: 0                   name  \
# 0             0                    트레저
# 1             1                  두아 리파
# 2             2                     싸이
# 3             3                    이문세
# 4             4                  SG워너비
# ..          ...                    ...
# 548         549                 육중완 밴드
# 549         550  CHO TOKIMEKI SENDENBU
# 550         551                    eaJ
# 551         552                 NEKIRU
# 552         553                  NMIXX
#
#                                                    url  0  gender
# 0    https://ticketimage.interpark.com/PlayDictiona...  1       1
# 1    https://ticketimage.interpark.com/PlayDictiona...  1       1
# 2    https://ticketimage.interpark.com/PlayDictiona...  0       0
# 3    https://ticketimage.interpark.com/PlayDictiona...  0       0
# 4    https://ticketimage.interpark.com/PlayDictiona...  0       0
# ..                                                 ... ..     ...
# ...

# %%
df = df.drop([0], axis=1)

# %%
df = df.drop(['Unnamed: 0'], axis=1)

# %%
df
# Out:
#                       name                                                url  \
# 0                      트레저  https://ticketimage.interpark.com/PlayDictiona...
# 1                    두아 리파  https://ticketimage.interpark.com/PlayDictiona...
# 2                       싸이  https://ticketimage.interpark.com/PlayDictiona...
# 3                      이문세  https://ticketimage.interpark.com/PlayDictiona...
# 4                    SG워너비  https://ticketimage.interpark.com/PlayDictiona...
# ..                     ...                                                ...
# 548                 육중완 밴드  https://i.namu.wiki/i/Bge3xnYd4kRe_IKbm2uqxlhQ...
# 549  CHO TOKIMEKI SENDENBU  https://i.namu.wiki/i/Bge3xnYd4kRe_IKbm2uqxlhQ...
# 550                    eaJ  https://i.namu.wiki/i/Bge3xnYd4kRe_IKbm2uqxlhQ...
# 551                 NEKIRU  https://i.namu.wiki/i/Bge3xnYd4kRe_IKbm2uqxlhQ...
# 552                  NMIXX  https://i.namu.wiki/i/Bge3xnYd4kRe_IKbm2uqxlhQ...
#
#      gender
# 0         1
# ...

# %% [markdown]
# ##### 아티스트가 솔로인지 그룹인지 표시해주는 컬럼 추가하기

# %%
df2 = np.random.randint(0,1+1, size=(552+1, 1))

# %%
df2.shape
# Out:
# (553, 1)

# %%
df2 = pd.DataFrame(df2, columns=['member'])

# %%
df = pd.concat([df, df2], axis=1)

# %% [markdown]
# ##### 아티스트 음악 장르 추가하기

# %%
df3 = np.random.randint(0,6+1, size=(552+1, 1))

# %%
df3.shape
# Out:
# (553, 1)

# %%
df3 = pd.DataFrame(df3, columns=['genre'])

# %%
df = pd.concat([df, df3], axis=1)

# %%
df.to_csv('../ticketMerge/artists_total(숫자).csv', index=False)

# %%
df
# Out:
#                       name                                                url  \
# 0                      트레저  https://ticketimage.interpark.com/PlayDictiona...
# 1                    두아 리파  https://ticketimage.interpark.com/PlayDictiona...
# 2                       싸이  https://ticketimage.interpark.com/PlayDictiona...
# 3                      이문세  https://ticketimage.interpark.com/PlayDictiona...
# 4                    SG워너비  https://ticketimage.interpark.com/PlayDictiona...
# ..                     ...                                                ...
# 548                 육중완 밴드  https://i.namu.wiki/i/Bge3xnYd4kRe_IKbm2uqxlhQ...
# 549  CHO TOKIMEKI SENDENBU  https://i.namu.wiki/i/Bge3xnYd4kRe_IKbm2uqxlhQ...
# 550                    eaJ  https://i.namu.wiki/i/Bge3xnYd4kRe_IKbm2uqxlhQ...
# 551                 NEKIRU  https://i.namu.wiki/i/Bge3xnYd4kRe_IKbm2uqxlhQ...
# 552                  NMIXX  https://i.namu.wiki/i/Bge3xnYd4kRe_IKbm2uqxlhQ...
#
#      gender  member  genre
# ...

# %%
df = df.replace({'gender': 0}, '남성')
df = df.replace({'gender': 1}, '여성')

# %%
df = df.replace({'member': 0}, '그룹')
df = df.replace({'member': 1}, '솔로')

# %%
df = df.replace({'genre': 0}, '발라드')
df = df.replace({'genre': 1}, '댄스')
df = df.replace({'genre': 2}, '힙합')
df = df.replace({'genre': 3}, '락')
df = df.replace({'genre': 4}, '트로트')
df = df.replace({'genre': 5}, '내한')
df = df.replace({'genre': 6}, '그 외')

# %%
df
# Out:
#                       name                                                url  \
# 0                      트레저  https://ticketimage.interpark.com/PlayDictiona...
# 1                    두아 리파  https://ticketimage.interpark.com/PlayDictiona...
# 2                       싸이  https://ticketimage.interpark.com/PlayDictiona...
# 3                      이문세  https://ticketimage.interpark.com/PlayDictiona...
# 4                    SG워너비  https://ticketimage.interpark.com/PlayDictiona...
# ..                     ...                                                ...
# 548                 육중완 밴드  https://i.namu.wiki/i/Bge3xnYd4kRe_IKbm2uqxlhQ...
# 549  CHO TOKIMEKI SENDENBU  https://i.namu.wiki/i/Bge3xnYd4kRe_IKbm2uqxlhQ...
# 550                    eaJ  https://i.namu.wiki/i/Bge3xnYd4kRe_IKbm2uqxlhQ...
# 551                 NEKIRU  https://i.namu.wiki/i/Bge3xnYd4kRe_IKbm2uqxlhQ...
# 552                  NMIXX  https://i.namu.wiki/i/Bge3xnYd4kRe_IKbm2uqxlhQ...
#
#     gender member genre
# ...

# %%
df.to_csv('../ticketMerge/artists_total(추가).csv' index=False)

# %% [markdown]
# ##### 7.8일 요구사항
# 지역 컬럼 수정 요청<br>
# 1.서울, 2. 경기/인천, 3. 강원/춘천/속초, 4. 충청/세종/대전, 5.전라/광주, 6. 경북/대구, 7. 경남/부산, 8. 제주<br>
# <br>16개 지역을 8개로 줄이기

# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('../ticketMerge/df_total(숫자).csv')

# %%
df
# Out:
#      Unnamed: 0                                              title  \
# 0             0   2024 TREASURE RELAY TOUR ［REBOOT］ FINAL IN SEOUL
# 1             1                                         두아 리파 내한공연
# 2             2                          싸이흠뻑쇼 SUMMERSWAG2024 - 인천
# 3             3                          송소희, 두번째달, 김준수의 모던민요 - 여주
# 4             4                          싸이흠뻑쇼 SUMMERSWAG2024 - 대구
# ..          ...                                                ...
# 504         504         프레드 허쉬 Solo Piano 2024 - Silent, Listening
# 505         505  CHO TOKIMEKI SENDENBU KIMINO HEART NI ROCK ON ...
# 506         506  eaJ Live in Seoul ＂when the rain stopped follo...
# 507         507    EMOTIONAL ORANGES LIVE IN SEOUL 이모셔널 오렌지스 내한 공연
# 508         508                      NEKIRU 5th ONEMAN LIVE 「낭만주의」
#
#                                           thumbnailUrl  \
# 0    http://ticketimage.interpark.com/Play/image/la...
# ...

# %%
df = df.drop(['Unnamed: 0'], axis=1)

# %%
# 'location' 컬럼에 새로 넣어줄 1~8까지의 랜덤 숫자가 들어있는 데이터프레임 만들어주기

# %%
loc = np.random.randint(1,8+1, size=(508+1, 1))

# %%
df_loc = pd.DataFrame(loc, columns=['location'])

# %%
df_loc
# Out:
#      location
# 0           4
# 1           6
# 2           8
# 3           3
# 4           8
# ..        ...
# 504         8
# 505         8
# 506         5
# 507         2
# 508         3
#
# [509 rows x 1 columns]

# %%
df['location'] = df_loc

# %%
df
# Out:
#                                                  title  \
# 0     2024 TREASURE RELAY TOUR ［REBOOT］ FINAL IN SEOUL
# 1                                           두아 리파 내한공연
# 2                            싸이흠뻑쇼 SUMMERSWAG2024 - 인천
# 3                            송소희, 두번째달, 김준수의 모던민요 - 여주
# 4                            싸이흠뻑쇼 SUMMERSWAG2024 - 대구
# ..                                                 ...
# 504         프레드 허쉬 Solo Piano 2024 - Silent, Listening
# 505  CHO TOKIMEKI SENDENBU KIMINO HEART NI ROCK ON ...
# 506  eaJ Live in Seoul ＂when the rain stopped follo...
# 507    EMOTIONAL ORANGES LIVE IN SEOUL 이모셔널 오렌지스 내한 공연
# 508                      NEKIRU 5th ONEMAN LIVE 「낭만주의」
#
#                                           thumbnailUrl  \
# 0    http://ticketimage.interpark.com/Play/image/la...
# 1    http://ticketimage.interpark.com/Play/image/la...
# 2    http://ticketimage.interpark.com/Play/image/la...
# 3    http://ticketimage.interpark.com/Play/image/la...
# ...

# %%
df.to_csv('../ticketMerge/df_total(지역수정_숫자).csv', index=False)

# %%
df['location'].unique()
# Out:
# array([4, 6, 8, 3, 7, 5, 1, 2])

# %%
df = df.replace({'location': 1}, '서울')
df = df.replace({'location': 2}, '경기/인천')
df = df.replace({'location': 3}, '강원/춘천/속초')
df = df.replace({'location': 4}, '충청/세종/대전')
df = df.replace({'location': 5}, '전라/광주')
df = df.replace({'location': 6}, '경북/대구')
df = df.replace({'location': 7}, '경남/부산')
df = df.replace({'location': 8}, '제주')

# %%
df
# Out:
#                                                  title  \
# 0     2024 TREASURE RELAY TOUR ［REBOOT］ FINAL IN SEOUL
# 1                                           두아 리파 내한공연
# 2                            싸이흠뻑쇼 SUMMERSWAG2024 - 인천
# 3                            송소희, 두번째달, 김준수의 모던민요 - 여주
# 4                            싸이흠뻑쇼 SUMMERSWAG2024 - 대구
# ..                                                 ...
# 504         프레드 허쉬 Solo Piano 2024 - Silent, Listening
# 505  CHO TOKIMEKI SENDENBU KIMINO HEART NI ROCK ON ...
# 506  eaJ Live in Seoul ＂when the rain stopped follo...
# 507    EMOTIONAL ORANGES LIVE IN SEOUL 이모셔널 오렌지스 내한 공연
# 508                      NEKIRU 5th ONEMAN LIVE 「낭만주의」
#
#                                           thumbnailUrl  \
# 0    http://ticketimage.interpark.com/Play/image/la...
# 1    http://ticketimage.interpark.com/Play/image/la...
# 2    http://ticketimage.interpark.com/Play/image/la...
# 3    http://ticketimage.interpark.com/Play/image/la...
# ...

# %%
df.to_csv('../ticketMerge/df_total(지역수정_문자).csv', index=False)
